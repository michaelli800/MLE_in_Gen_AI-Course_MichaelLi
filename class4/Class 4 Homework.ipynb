# %% [markdown]
# # Week 4: Retrieval-Augmented Generation (RAG) with arXiv Papers
# This week marks a major shift in your AI agent's capabilities: you’ll build the foundation for a Retrieval-Augmented Generation (RAG) system tailored to scientific research. Rather than relying on an LLM’s memory alone, RAG architectures allow your agent to search a structured knowledge base and generate grounded, document-aware answers.
#
# Your task is to create a RAG pipeline using recent arXiv cs.CL papers, converting them into searchable chunks, embedding them, and indexing them with FAISS. You’ll then implement a simple query interface that takes a user question, retrieves the top relevant chunks, and displays them for further processing.
#
# This week marks the beginning of building your agent’s private research knowledge base—a semantic index that you’ll evolve into a full-featured hybrid database in Week 5.

# %% [markdown]
# ## 📚 Learning Objectives
#
# * Understand the components of a Retriever-Reader QA pipeline.
# * Explore document chunking strategies (e.g., sections vs. sliding windows) and their impact on retrieval performance.
# * Index scientific text using vector embeddings and FAISS.
# * Build and query a semantic index via a FastAPI endpoint that returns relevant passages.

# %% [markdown]
# ## Project Design
#
# The project will guide you through building a RAG pipeline on arXiv cs.CL papers:
#
# 1. **Data Collection:** Obtain 50 arXiv cs.CL PDFs (you can scrape via the arXiv API or use a provided sample set).
# 2. **Text Extraction:** Extract raw text from each PDF (for example, using PyMuPDF's `get_text()` on each page). Clean and concatenate the page text into full-document strings.
# 3. **Text Chunking:** Split each paper into chunks (≤ 512 tokens each). You might split at section boundaries or use a sliding-window approach (e.g., 500-token windows with overlap). Chunking into smaller, meaningful segments (around 250–512 tokens) often yields better retrieval precision.
# 4. **Embedding Generation:** Compute dense vector embeddings for each chunk. For instance, using the `sentence-transformers` library:

# %%
from langchain.document_loaders import PyPDFLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
# 1. Load your documents
resume = PyPDFLoader("./python-developer-resume-example.pdf").load()
extras = TextLoader("./portfolio_notes.txt").load()
docs = resume + extras
print("Documents:")
print(docs) 
# 2. Split documents into chunks
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)
print("Doc Chunks:")
print(chunks)

with open("my_text_file.txt", "r") as f:
    text = f.read()

textList = text.splitlines()  
print("Text Lines:")
print(textList)   
# Split by paragraphs
list_of_chunks = [chunk.strip() for chunk in textList if chunk.strip()]

print("Paragraph Chunks:")
print(list_of_chunks)
# Out:
# Documents:
# [Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='GIULIA\nGONZALEZ\nPython Developer\nggonzalez@email.com\n(123) 456-7890\nDetroit, MI\nLinkedIn\nGithub\nEDUCATION\nM.S.\nComputer Science\nUniversity of Chicago\n2014 - 2016\nChicago, IL\nB.S.\nComputer Science\nUniversity of Pittsburgh\n2010 - 2014\nPittsburgh, PA\nSKILLS\nHTML/ CSS\nSQL (PostgreSQL, Oracle)\nJavaScript (Angular)\nPython (Django)\nREST APIs (GraphQL)\nAWS (Redshift, S3)\nGit\nWORK EXPERIENCE\nPython Developer\nDoorDash\nSeptember 2017 - current Detroit, MI\n· Worked on building new Angular components for the customer-\nfacing web app, which improved the time on page for the\naverage user by 2 minutes\n· Collaborated with an agile team of 6, and helped prioritize and\nscope feature requests to ensure that the biggest impact\nfeatures were worked on ﬁrst\n· Built extensive test coverage for all new features, which reduced\nthe number of customer complaints by 23%\n· Acquired and ingested data to build and maintain data pipelines\nthat led to discovering an opportunity for a new site feature,\nboosting revenue by 6%\n· Communicated with internal teams and stakeholders, working\nto determine solutions for the user experience\nPython Developer Intern\nKnewton\nApril 2016 - April 2017 Chicago, IL\n· Worked alongside another developer to implement RESTful APIs\nin Django that enabled internal analytics team to increase\nreporting speed by 24%\n· Using Selenium, built out a unit testing infrastructure for a client\nweb application that reduced the number of bugs reported by\nthe client by 11% month over month\n· Provided project updates to leadership team of 3, and oﬀered\nrecommendations for design\n· Diagnosed issues causing slow speeds in applications, and\ndocumented the process to making the database query system\nmore robust\n· Participated in writing scalable code with a team of 4 interns\nand 1 developer for applications for a math course\nPROJECTS\nCryptocurrency Price Tracker\nCreator\n· Incorporated API calls to several applications, and stored data\neﬃciently in PostgreSQL backend\n· Utilized D3.js to allow users to dynamically visualize price\nmovements over time periods of their choosing'), Document(metadata={'source': './portfolio_notes.txt'}, page_content="## Career Summary\n\nI'm a Python developer with a strong foundation in backend development, frontend components, and scalable data workflows. I've worked in fast-paced environments like DoorDash and Knewton, where I contributed to production-grade systems, internal tools, and data infrastructure.\n\n## Experience Highlight: Angular at DoorDash\n\nAt DoorDash, I contributed new Angular components to the customer-facing web app. These enhancements directly improved average user time-on-page by 2 minutes, reflecting more engaging UI/UX outcomes. My focus was not only on front-end polish but also aligning with backend services through REST APIs.\n\n## Team Collaboration & Agile\n\nI worked in a 6-person agile team, regularly collaborating with product managers to prioritize features that delivered measurable customer and business impact. One example was a new data pipeline I developed that led to a product idea that ultimately increased revenue by 6%.\n\n## Quality Engineering & Testing Mindset\n\nAt both DoorDash and Knewton, I emphasized code quality. I implemented extensive test coverage on new features at DoorDash, which cut customer complaints by 23%. Earlier, at Knewton, I helped build a Selenium-based testing infrastructure that reduced monthly bug reports by 11%.\n\n## Data Pipelines & Product Insight\n\nOne of my biggest technical wins was ingesting and transforming large datasets at DoorDash, which revealed user behavior patterns that led to product feature proposals. I built robus ...
# Doc Chunks:
# [Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='GIULIA\nGONZALEZ\nPython Developer\nggonzalez@email.com\n(123) 456-7890\nDetroit, MI\nLinkedIn\nGithub\nEDUCATION\nM.S.\nComputer Science\nUniversity of Chicago\n2014 - 2016\nChicago, IL\nB.S.\nComputer Science\nUniversity of Pittsburgh\n2010 - 2014\nPittsburgh, PA\nSKILLS\nHTML/ CSS\nSQL (PostgreSQL, Oracle)\nJavaScript (Angular)\nPython (Django)\nREST APIs (GraphQL)\nAWS (Redshift, S3)\nGit\nWORK EXPERIENCE\nPython Developer\nDoorDash\nSeptember 2017 - current Detroit, MI'), Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='DoorDash\nSeptember 2017 - current Detroit, MI\n· Worked on building new Angular components for the customer-\nfacing web app, which improved the time on page for the\naverage user by 2 minutes\n· Collaborated with an agile team of 6, and helped prioritize and\nscope feature requests to ensure that the biggest impact\nfeatures were worked on ﬁrst\n· Built extensive test coverage for all new features, which reduced\nthe number of customer complaints by 23%'), Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='the number of customer complaints by 23%\n· Acquired and ingested data to build and maintain data pipelines\nthat led to discovering an opportunity for a new site feature,\nboosting revenue by 6%\n· Communicated with internal teams and stakeholders, working\nto determine solutions for the user experience\nPython Developer Intern\nKnewton\nApril 2016 - April 2017 Chicago, IL\n· Worked alongside another developer to implement RESTful APIs\nin Django that enabled internal analytics team to increase'), Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='reporting speed by 24%\n· Using Selenium, built out a unit testing infrastructure for a client\nweb application that reduced the number of bugs reported by\nthe client by 11% month over month\n· Provided project updates to leadership team of 3, and oﬀered\nrecommendations for design\n· Diagnosed issues causing slow speeds in applications, and\ndocumented the process to making the database query system\nmore robust\n· Participated in writing scalable code with a team of 4 interns'), Document(metadata={'producer': 'PDFShift.io', 'creator': 'PyPDF', 'creationdate': '2021-10-08T18:00:57+00:00', 'moddate': '2021-10-08T18:00:57+00:00', 'source': './python-developer-resume-example.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='and 1 developer for applications for a math course\nPROJECTS\nCryptocurrency Price Tracker\nCreator\n· Incorporated API calls to several applications, and stored data\neﬃciently in PostgreSQL backend\n· Utilized D3.js to allow users to dynamically visualize price\nmovements over time periods of their choosing'), Document(metadata={'source': './portfolio_notes.txt'}, page_content="## Career Summary\n\nI'm a Python developer with a strong foundation in backend development, frontend components, and scalable data workflows. I've worked in fast-paced environments like DoorDash and Knewton, where I contributed to production-grade systems, internal tools, and data infrastructure.\n\n## Experience Highlight: Angular at DoorDash"), Docum ...
# Paragraph Chunks:
# ['Retrieval-Augmented Generation (RAG) is a technique that combines information retrieval with text generation. It enhances the capabilities of language models by providing them with access to external knowledge sources.', 'Text embeddings are numerical representations of text that capture semantic meaning. They are used to measure similarity between pieces of text.', 'Vector databases store these embeddings and allow for efficient similarity searches.', 'LangChain is a framework that facilitates the development of applications powered by language models. It provides tools for integrating LLMs with external data sources.', 'Evaluation metrics for RAG systems include precision, recall, and F1 score, which assess the quality of the generated responses.']

# %%
from sentence_transformers import SentenceTransformer
'''
list_of_chunks = [
    "Giulia contributed to a Python project focused on predictive analytics for stock market trends, using libraries like Pandas and Scikit-learn.",
    "Another key project was a Flask web application that serves real-time machine learning inference, deployed using Docker containers.",
    "The third major project involved developing custom data pipelines with Apache Kafka for high-throughput data ingestion.",
    "General information: The candidate has a background in Computer Science and 5 years of professional experience.",
]
'''
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(list_of_chunks)  # embeds each text chunk into a 384-d vecto
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1621, in SentenceTransformer.tokenize(self, texts, **kwargs)
#    1620 try:
# -> 1621     return self[0].tokenize(texts, **kwargs)
#    1622 except TypeError:
#
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:308, in Transformer.tokenize(self, texts, padding)
#     307 for text_tuple in texts:
# --> 308     batch1.append(text_tuple[0])
#     309     batch2.append(text_tuple[1])
#
# TypeError: 'Document' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       2 '''
#       3 list_of_chunks = [
#       4     "Giulia contributed to a Python project focused on predictive analytics for stock market trends, using libraries like Pandas and Scikit-learn.",
#    (...)      8 ]
#       9 '''
#      10 model = SentenceTransformer('all-MiniLM-L6-v2')
# ---> 11 embeddings = model.encode(list_of_chunks)  # embeds each text chunk into a 384-d vecto
#
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1062, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1060 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#    1061     sentences_batch = sentences_sorted[start_index : start_index + batch_size]
# -> 1062     features = self.tokenize(sentences_batch, **kwargs)
#    1063     if self.device.type == "hpu":
#    1064         if "input_ids" in features:
#
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1623, in SentenceTransformer.tokenize(self, texts, **kwargs)
#    1621     return self[0].tokenize(texts, **kwargs)
#    1622 except TypeError:
# -> 1623     return self[0].tokenize(texts)
#
# File ~/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:308, in Transformer.tokenize(self, texts, padding)
#     306 batch1, batch2 = [], []
#     307 for text_tuple in texts:
# --> 308     batch1.append(text_tuple[0])
#     309     batch2.append(text_tuple[1])
#     310 to_tokenize = [batch1, batch2]
#
# TypeError: 'Document' object is not subscriptable

# %% [markdown]
#    (Alternatively, you can use a Hugging Face Transformer model and apply pooling manually to get chunk embeddings.)
# 5. **Indexing with FAISS:** Build a FAISS index of the chunk embeddings. For example, use a simple index like `IndexFlatL2` with the same dimensionality as your embeddings. Add all chunk vectors to the index (e.g., `index.add(np.array(embeddings))`).
# 6. **Notebook Demo:** Create a notebook where a user query is embedded and passed to the index (`index.search(query_embedding, k)`) to retrieve the top-3 matching chunks. Display the original chunk text for these results.
# 7. **FastAPI Service:** Build a simple FastAPI app. Define an endpoint (e.g. `@app.get("/search")`) that accepts a query parameter `q`. In the handler, embed `q`, perform the FAISS search, and return the top passages as JSON. (For example, a FastAPI endpoint can accept a question and return relevant documents.)

# %%
! pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.26.6-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.6-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 60.8 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.26.6
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Starter Code Snippets
#
# Below are skeleton code templates. Fill in the details (indicated by comments or ellipses).
#
# **Data Extraction (PDF → Text):**

# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path: str) -> str:
    """
    Open a PDF and extract all text as a single string.
    """
    doc = fitz.open(pdf_path)
    pages = []
    for page in doc:
        page_text = page.get_text()  # get raw text from page
        # (Optional) clean page_text here (remove headers/footers)
        pages.append(page_text)
    full_text = "\n".join(pages)
    return full_text

# %% [markdown]
# **Chunking Logic (Sliding Window):**

# %%
from typing import List
def chunk_text(text: str, max_tokens: int = 512, overlap: int = 50) -> List[str]:
    tokens = text.split()
    chunks = []
    step = max_tokens - overlap
    for i in range(0, len(tokens), step):
        chunk = tokens[i:i + max_tokens]
        chunks.append(" ".join(chunk))
    return chunks

# %% [markdown]
# **Embedding Generation (Sentence-Transformers):**

# %%
def chunk_text(text: str, max_tokens: int = 512, overlap: int = 50) -> List[str]:
    tokens = text.split()
    chunks = []
    step = max_tokens - overlap
    for i in range(0, len(tokens), step):
        chunk = tokens[i:i + max_tokens]
        chunks.append(" ".join(chunk))
    return chunks

# %%
! pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in ./venv311/lib/python3.11/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in ./venv311/lib/python3.11/site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.13.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 6.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.1
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **FAISS Indexing and Search:**

# %%
import faiss
import numpy as np

# --- Placeholder Data Setup ---
# Define the parameters
num_chunks = 10
dim = 768  # Common dimension for large language model embeddings (e.g., BERT, OpenAI)
k = 3

# 1. Create a dummy embeddings array (the "database" of chunk vectors)
# Assume embeddings is a 2D numpy array of shape (num_chunks, dim)
# Note: FAISS requires float32 for its arrays
np.random.seed(42) # for reproducibility
embeddings = np.random.rand(num_chunks, dim).astype('float32')

# 2. Create a dummy query embedding
# This would typically be the embedding of the user's question.
# It must have the shape [1, dim] and be float32.
# We'll just pick a random row from the existing embeddings to ensure a good match.
query_embedding = embeddings[5:6] # Slice [5:6] keeps the shape [1, dim]
# ------------------------------


# --- FAISS Indexing ---
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)  # using a simple L2 index (Euclidean distance)
print(f"Adding {embeddings.shape[0]} vectors of dimension {dim} to the index...")
index.add(np.array(embeddings))  # add all chunk vectors

# Check the index size
print(f"Total vectors in index: {index.ntotal}")


# --- FAISS Search ---
# Example: search for a query embedding
# query_embedding = ...  # get embedding for the query (shape: [1, dim])

print(f"\nSearching for the top {k} nearest neighbors...")
distances, indices = index.search(query_embedding, k)

# The result of the search
# distances: [[d1, d2, d3]] -> The distances to the top-k neighbors
# indices: [[i1, i2, i3]] -> The original row indices (0 to num_chunks-1) of the top-k neighbors

print(f"Top {k} chunk indices found: {indices[0]}")
print(f"Distances to those chunks: {distances[0]}")
# indices[0] holds the top-k chunk indices
# Out:
# Adding 10 vectors of dimension 768 to the index...
# Total vectors in index: 10
#
# Searching for the top 3 nearest neighbors...
# Top 3 chunk indices found: [5 9 2]
# Distances to those chunks: [  0.       120.852875 122.26363 ]

# %%
import faiss
import numpy as np

# Assume embeddings is a 2D numpy array of shape (num_chunks, dim)
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)  # using a simple L2 index
index.add(np.array(embeddings))  # add all chunk vectors

# Example: search for a query embedding
query_embedding = ...  # get embedding for the query (shape: [1, dim])
k = 3
distances, indices = index.search(query_embedding, k)
# indices[0] holds the top-k chunk indices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 import numpy as np
#       4 # Assume embeddings is a 2D numpy array of shape (num_chunks, dim)
# ----> 5 dim = embeddings.shape[1]
#       6 index = faiss.IndexFlatL2(dim)  # using a simple L2 index
#       7 index.add(np.array(embeddings))  # add all chunk vectors
#
# NameError: name 'embeddings' is not defined

# %% [markdown]
# **FastAPI Route Skeleton:**

# %%
! pip install fastapi uvicorn
# Out:
# Collecting fastapi
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: uvicorn in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (0.40.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi)
#   Using cached starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from fastapi) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: click>=7.0 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from pydantic>=2.7.0->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/icha/miniconda3/envs/py3118_c4_l/lib/python3.11/site-packages (from pydantic>=2.7.0->fastapi) (0.4.2)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Using cached starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Installing collected packages: annotated-doc, starlette, fastapi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fastapi]
# Successfully installed annotated-doc-0.0.4 fastapi-0.128.0 starlette-0.50.0

# %%
from fastapi import FastAPI
import numpy as np

app = FastAPI()

@app.get("/search")
async def search(q: str):
    """
    Receive a query 'q', embed it, retrieve top-3 passages, and return them.
    """
    # TODO: Embed the query 'q' using your embedding model
    query_vector = ...  # e.g., model.encode([q])[0]
    # Perform FAISS search
    k = 3
    distances, indices = faiss_index.search(np.array([query_vector]), k)
    # Retrieve the corresponding chunks (assuming 'chunks' list and 'indices' shape [1, k])
    results = []
    for idx in indices[0]:
        results.append(chunks[idx])
    return {"query": q, "results": results}

# %% [markdown]
# ## Deliverables
#
# * **Code Notebook / Script:** Complete code for the RAG pipeline (PDF extraction, chunking, embedding, indexing, retrieval).
# * **Data & Index:** The FAISS index file and the set of 50 processed paper chunks (e.g., as JSON or pickled objects).
# * **Retrieval Report:** A brief report showing at least 5 example queries and the top-3 retrieved passages for each, to demonstrate system performance.
# * **FastAPI Service:** The FastAPI app code (e.g. `main.py`) and instructions on how to run it. The `/search` endpoint should be demonstrable (e.g. returning top-3 passages in JSON for sample queries).
#
# ## Student Exploration Tips
#
# * Experiment with different chunk sizes and overlaps. Smaller chunks (∼250 tokens) often give more precise retrieval, while larger chunks include more context.
# * Try different embedding models (e.g. using `'all-mpnet-base-v2'` or `'paraphrase-MiniLM-L6-v2'`) to see how retrieval results change.
# * Implement a simple reranking step: for example, after retrieving candidates with FAISS, re-score them with a cross-encoder model for finer ranking.
# * Use metadata: consider filtering or weighting chunks by paper metadata (e.g. year, authors, keywords) to improve relevance if needed.
